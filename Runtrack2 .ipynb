# %% [markdown]
# ## Job 0 :

# %% [markdown]
# Créez une classe “Personne” avec les attributs “nom”, “prenom”. Ajoutez une méthode “SePresenter()” qui affichera dans le terminal le nom et le prénom de la personne. Ajoutez aussi un constructeur prenant en paramètres de quoi donner des valeurs initiales aux attributs “nom” et “prenom”. Instanciez plusieurs personnes avec les valeurs de construction de votre choix et faites appel à la méthode “SePresenter()” afin de vérifier que tout fonctionne correctement. Ajouter un “accesseur” et un “mutateur” pour chacun des attributs.

# %%
class personne(object):# object indique que la classe est la racine.
    def __init__(self,nom='AIT LAZIZ',prenom='Yasser'):
        self.nom=nom
        self.prenom=prenom
    def sePresenter(self):
        return self.nom+' '+self.prenom
    def get_personne(self):
        return self.nom,self.prenom
    def set_personne(self,nv_nom,nv_prenom):
        self.nom=nv_nom
        self.prenom=nv_prenom
        return self.nom+' '+self.prenom
    
Per1=personne('AIT','Ahmed')
print(Per1.sePresenter())
print(Per1.get_personne())
print(Per1.set_personne('AIT MELO', 'Doha'))
# Out:
# AIT Ahmed
# ('AIT', 'Ahmed')
# AIT MELO Doha

# %% [markdown]
# ## Job 1 :

# %% [markdown]
# Créer une classe “Livre” avec comme attribut un “titre” qu’elle reçoit en paramètre à la construction et une référence vers une classe “Auteur”.
# Ajouter une méthode “print” permettant d’afficher dans le terminal le titre du livre.\\\
# Créer une classe “Auteur” héritant de la classe “Personne” recevant un nom et un prénom en paramètre de construction.\\\
# La classe auteur devra posséder une collection de livres nommée "œuvre" en attribut ainsi qu’une méthode “listerOeuvre” affichant dans le terminal la liste des livres écrits par l’auteur.\\\
# Ajouter à la classe Auteur une méthode “ecrireUnLivre” prenant en paramètre un titre de livre à écrire et générer une instance de la classe livre avec ce titre. \\\
# Ajouter ce nouveau livre à l’oeuvre de l’auteur

# %%
class livre(object):
    def __init__(self,titre,reference):
        self.titre=titre
        self.reference=reference #composition !!
        self.reference.ecrireUnLivre(titre) #composition !!
    def print_livre(self):
        return self.__titre
    
        
class Auteur(Personne):
    def __init__(self,nom,prenom,oeuvre):
        self.oeuvre=oeuvre
        Personne.__init__(self,nom,prenom)
    def listerOeuvre(self):
        return self.oeuvre
    def ecrireUnLivre(self,titre_ecrit):
        self.oeuvre+=[str(titre_ecrit)]
        
        

auteur1=Auteur('Hugo','Victor',['livre_1'])
livre_nv=livre('livre_new',auteur1)
auteur1=Auteur('Hugo','Victor',auteur1.listerOeuvre())
livre_nv=livre('livre_new2',auteur1)
auteur1.listerOeuvre()
# Out:
# ['livre_1', 'livre_new', 'livre_new2']

# %% [markdown]
# ## Job 02.718

# %% [markdown]
# Créer une classe “Client” héritant de “Personne”, prenant en paramètre un nom et un prenom.\\\
# \\\
# Créez une classe “Bibliotheque” avec comme attributs un nom et un catalogue: une
# collection de livres ou chaque livre est associé à une quantité (représenté par un
# nombre entier). Ajoutez les méthodes suivantes :\\\
# - acheterLivre: Prenant en paramètre un objet auteur, le nom d’un livre ainsi qu’un
# nombre entier représentant une quantité. Si le livre existe bien dans l'œuvre de
# l’auteur, ajouter ce livre au catalogue de la bibliothèque avec la quantité
# correspondante.\\\
# - inventaire: Une méthode qui affiche dans le terminal les titres des livres présents
# dans le catalogue ainsi que leur quantité.\\\
# - louer: Cette méthode reçoit en paramètres une instance d’objet “Client” ainsi que
# le nom d’un livre. Si le livre existe et est en stock, ajoutez ce livre à la collection
# de livre du client et tenez à jour la quantité de ce livre dans la bibliothèque.\\\
# - rendreLivres: Une méthode qui prend un “Client” en paramètre et qui récupère
# tous les livres de ce dernier et les ajoute au catalogue de la bibliothèque.\\\
# Ajouter à la classe “Client” un attribut collection étant une collection de livres et ajouter
# la méthode inventaire qui affiche dans le terminal les titres des livres en possession du
# client.\\\
# Ensuite, instanciez des auteurs, faites leurs écrire des livres, créer des bibliothèques,
# faites les acheter des livres, créez des clients, faites les louer des livres puis utilisez des
# fonctions d'affichage et montrez le résultat à votre examinateur.

# %%
class Client(Personne):
    def __init__(self,nom,prenom,collection_client=[]):
        self.collection_client=collection_client #liste
        Personne.__init__(self,nom,prenom)
    def additionner_collection(self,elmt):
        self.collection_client+=[str(elmt)]
    def inventaire(self):
         print(self.collection_client)
        
        
class Bibliotheque(object):
    def __init__(self,nom,catalogue):
        self.nom=nom
        self.catalogue=catalogue #dictionnaire
    def acheterLivre(self,auteur,nom_livre,quantite):
        if nom_livre in auteur.listerOeuvre():
            self.catalogue.update({nom_livre : quantite})
    def inventaire(self):
        print(self.catalogue)
    def louer(self,client,nom_livre):
        if self.catalogue[nom_livre]>0:
            client.additionner_collection(nom_livre)
            self.catalogue[nom_livre]=self.catalogue[nom_livre]-1 #mise à jour de la biblio
    def rendreLivres(self,client):
        for livre in client.collection_client :
            if livre in list(self.catalogue.keys()):
                self.catalogue[livre]+=1
            else:
                self.catalogue.update({livre:1})
            client.collection_client=[]
        
            
        
auteur_1=Auteur('Alan','walker',['livre_X1','livre_X2','livre_X3'])   
auteur_2=Auteur('Doha','Boba',['livre_Y1','livre_Y2','livre_Y3']) 
bibliothéque_1=Bibliotheque('Al Qods',{})

bibliothéque_1.acheterLivre(auteur_1,'livre_X1',5)
bibliothéque_1.acheterLivre(auteur_1,'livre_X2',10)
bibliothéque_1.acheterLivre(auteur_1,'livre_X3',15)
bibliothéque_1.acheterLivre(auteur_2,'livre_Y1',50)
bibliothéque_1.acheterLivre(auteur_2,'livre_Y2',100)
bibliothéque_1.acheterLivre(auteur_2,'livre_Y3',150)
bibliothéque_1.inventaire()

client_1=Client('clientNom1','clientPrenom1',[])
client_2=Client('clientNom2','clientPrenom2',['livre_ancien'])

bibliothéque_1.louer(client_1,'livre_X1')
bibliothéque_1.louer(client_2,'livre_Y1')

client_1.inventaire()
client_2.inventaire()

bibliothéque_1.inventaire()

bibliothéque_1.rendreLivres(client_1)
bibliothéque_1.rendreLivres(client_2)

bibliothéque_1.inventaire()

client_1.inventaire()
client_2.inventaire()
# Out:
# {'livre_X1': 5, 'livre_X2': 10, 'livre_X3': 15, 'livre_Y1': 50, 'livre_Y2': 100, 'livre_Y3': 150}
# ['livre_X1']
# ['livre_ancien', 'livre_Y1']
# {'livre_X1': 4, 'livre_X2': 10, 'livre_X3': 15, 'livre_Y1': 49, 'livre_Y2': 100, 'livre_Y3': 150}
# {'livre_X1': 5, 'livre_X2': 10, 'livre_X3': 15, 'livre_Y1': 50, 'livre_Y2': 100, 'livre_Y3': 150, 'livre_ancien': 1}
# []
# []

# %% [markdown]
# ## Job 07.389

# %% [markdown]
# Vous allez créer dans ce Job un jeu de puissance 4 sur plateau de taille variable ainsi qu’un algorithme qui sera capable de jouer des coups mesurés.\\\
# Commencez par créer une classe “Board” prenant en paramètres de construction deux entiers i et j.
# \\\Créez un attribut, sous la forme d’un tableau à 2 dimensions, représentant un plateau de jeu en deux dimensions de taille i x j. \\\
# Ce tableau représente:
# - les cases vides par des O
# - les jetons jaunes par des J
# - les jetons rouges par des R\\
# Créez une méthode “play” qui prend en paramètres un nombre entier ainsi qu’une chaine de caracteres pouvant être “rouge” ou “jaune”. \\\Le nombre entier correspond à la colonne dans laquelle un jeton de jeu est inséré et la couleur correspond à la couleur du joueur jouant ce jeton. Après un coup, tenez à jour votre plateau de jeu en plaçant le jeton le plus bas possible dans la colonne où il a été joué.
# \\
# Ajouter une méthode “print” affichant dans le terminal l’état du plateau de jeu. \\\ Implémentez le déroulement d’une partie en demandant aux joueurs humains de jouer à tour de rôle en choisissant la colonne dans laquelle ils souhaitent insérer leurs jetons.\\\
# Le premier joueur à aligner 4 jetons de sa couleur gagne la partie et reçoit 100 000 euros.

# %%
import numpy as np

class Board(object): 
    def __init__(self,i=4,j=4):
        self.i=i
        self.j=j
        self.plateau=np.full((self.i,self.j),'O' )
        self.list_colonne_complète=[]
    def play(self,mvt,couleur):
        if mvt>self.j:
            return print('La Valeur de la colonne insérée est hors plateau ! Tentez un entier entre 0 et',self.j)
        couleur=couleur.lower() # meme si le string entré est en maj, il devient en miniscule comme demandé en instruction.
        mvt=mvt-1
        if couleur=='rouge' or couleur=='jaune':
            #for a in range(self.i): # i = la valeur maximal des lignes = dernière ligne.
                #if self.plateau[self.i-1][mvt]== 'O' :
                    #self.plateau[self.i-1][mvt]=couleur
                    #break
                #else :
                    #self.plateau[self.i-1-a][mvt]=couleur
                    #break
            for a in range(self.i):
                if self.plateau[self.i-1-a][mvt]== 'O':
                    self.plateau[self.i-1-a][mvt]=couleur
                    break
            if self.plateau[0][mvt]!= 'O':
                self.list_colonne_complète.append(mvt)
                return print('joueur',couleur,'a saturé complètement la colonne',mvt
                             ,'! Voici la liste des colonnes saturés',self.list_colonne_complète)
        # appeler la méthode verfication_gagnant.
        # Check sur les colonnes:
        for b in range(self.j): #self.j ici correspond à la dernière colonne.
                A=[]
                for i in range(self.i):# hona
                    A.append(str(self.plateau[i][b]))
                A1=A
                A2=A
                for i in range(len(A1)):
                    if A1.count('r')>=4:
                        B=[]
                        c1=A1.index('r')
                        for j in range(4):
                            B.append(A1[c1+j])
                        if B.count('r')==4:
                            return print('le rouge à gagner !! Partie Terminée')
                        else:
                            A1.remove(A1[A1.index('r')])
                    if A2.count('j')>=4:
                        B2=[]
                        c2=A2.index('j')
                        for j in range(4):
                            B2.append(A2[c2+j])
                        if B2.count('j')==4:
                            return print('le jaune à gagner !! Partie Terminée')
                        else:
                            A2.remove(A2[c2])
                #if A.count('r')==4 :
                    #return print('le rouge à gagner !! Partie Terminée')
                    
                #if A.count('j')==4:
                    #return print('le jaune à gagner !! Partie Terminée')
        # Check sur les lignes:
        for a in range(self.i):
            A=[]
            for i in range(self.j):#hona
                A.append(str(self.plateau[a][i]))
                A1=A
                A2=A
                for i in range(len(A1)):
                    if A1.count('r')>=4:
                        B=[]
                        c1=A1.index('r')
                        for j in range(4):
                            B.append(A1[c1+j])
                        if B.count('r')==4:
                            return print('le rouge @ gagné !! Partie Terminée')
                        else:
                            A1.remove(A1[A1.index('r')])
                    if A2.count('j')>=4:
                        B2=[]
                        c2=A2.index('j')
                        for j in range(4):
                            B2.append(A2[c2+j])
                        if B2.count('j')==4:
                            return print('le jaune @ gagné !! Partie Terminée')
                        else:
                            A2.remove(A2[c2])
            #if A.count('r')==4 :
                    #return print('le rouge a gagné !! Partie Terminée')
            #if A.count('j')==4 :
                   # return print('le jaune a gagné !! Partie Terminée')
     
        # check les lignes diagonaux :
        if self.i>self.j>4 :
            # cas 1 :
            D1=[]
            c=4
            v=self.i-4
            z=self.i-1
            b=self.j
            for i in range(c):
                D1.append(str(self.plateau[v+i][b-1-i]))
                print(D1,v,c,v+i-z)
                if v+i==z:
                    print('jesuis enctrée ici !! ')
                    v=v+1
                    c=c+1
                    print('valeur de v =',v,'valeur de c=',c)
                    
                    if c>self.j:
                        c=self.j
                    A1=D1
                    A2=D1
                    for y in range(len(A1)):
                        if 'r' in A1:
                            B=[]
                            c1=A1.index('r')
                            for j in range(4):
                                if c1+j>len(A1)-1:
                                    break
                                B.append(A1[c1+j])
                            if B.count('r')==4:
                                return print('le rouge a gagné !! Partie Terminée')
                            else:
                                A1.remove(A1[A1.index('r')])
                        elif 'j' in A1:
                            B2=[]
                            c2=A2.index('j')
                            for j in range(4):
                                if c2+j>len(A1)-1:
                                    break
                                B2.append(A2[c2+j])
                            if B2.count('j')==4:
                                return print('le jaune a gagné !! Partie Terminée')
                            else:
                                A2.remove(A2[c2])
                        #if D1.count('r')==4 :
                            #return print('le rouge a gagné !! Partie Terminée')
                        #if D1.count('j')==4 :
                            #return print('le jaune a gagné !! Partie Terminée')
                        print('ICI 2222 valeur de v =',v,'valeur de c=',c)             
                #if b-1-i==0:
                #    z-=1
                #if v==0:
                #    b-=1
                #    c-=1
                print('Anne - valeur de v =',v,'valeur de c=',c)
            print('\n' + '------------------------------------------------------------------')
                    
            
                    
            
            
                        
        
        
    def print_t(self):
        return print(self.plateau)
        
        
board_test=Board(6,5)
board_test.play(5,'jaune')
board_test.play(5,'jaune')

board_test.print_t()
# Out:
# ['O'] 2 4 -3
# valeur de v = 2 valeur de c= 4
# ['O', 'O'] 2 4 -2
# valeur de v = 2 valeur de c= 4
# ['O', 'O', 'O'] 2 4 -1
# valeur de v = 2 valeur de c= 4
# ['O', 'O', 'O', 'O'] 2 4 0
# jesuis enctrée ici !!
# valeur de v = 3 valeur de c= 5
# ICI 2222 valeur de v = 3 valeur de c= 5
# ICI 2222 valeur de v = 3 valeur de c= 5
# ICI 2222 valeur de v = 3 valeur de c= 5
# ICI 2222 valeur de v = 3 valeur de c= 5
# valeur de v = 3 valeur de c= 5
#
# ------------------------------------------------------------------
# ['O'] 2 4 -3
# valeur de v = 2 valeur de c= 4
# ['O', 'O'] 2 4 -2
# valeur de v = 2 valeur de c= 4
# ['O', 'O', 'O'] 2 4 -1
# valeur de v = 2 valeur de c= 4
# ['O', 'O', 'O', 'O'] 2 4 0
# jesuis enctrée ici !!
# valeur de v = 3 valeur de c= 5
# ICI 2222 valeur de v = 3 valeur de c= 5
# ICI 2222 valeur de v = 3 valeur de c= 5
# ICI 2222 valeur de v = 3 valeur de c= 5
# ICI 2222 valeur de v = 3 valeur de c= 5
# valeur de v = 3 valeur de c= 5
#
# ...

# %%
a1=0
a2=0
for i in range(c): pour i = 0 a1 =
    ---------
    ---------
    
    --------
    a1+=1
    a2+=2

# %%
#board_test.print_t()
board_test.play(5,'jaune')
#board_test.print_t()
board_test.play(5,'jaune')
#board_test.print_t()
board_test.play(5,'rouge')
#board_test.print_t()
board_test.play(5,'jaune')
#board_test.print_t()
board_test.play(5,'rouge')
#board_test.print_t()
board_test.play(4,'jaune')
#board_test.print_t()
board_test.play(4,'rouge')
#board_test.print_t()
board_test.play(4,'jaune')
#board_test.print_t()
board_test.play(3,'rouge')
#board_test.print_t()
board_test.play(3,'rouge')
#board_test.print_t()
board_test.play(2,'rouge')
#board_test.print_t()
board_test.play(1,'rouge')
#board_test.print_t()
board_test.play(2,'rouge')
#board_test.print_t()
board_test.play(3,'rouge')
#board_test.print_t()
board_test.play(4,'rouge')

# %%
import numpy as np

class Board(object): 
    def __init__(self,i=4,j=4):
        self.i=i
        self.j=j
        self.plateau=np.full((self.i,self.j),'O' )
        self.list_colonne_complète=[]
        self.c=0
        self.v=0
        self.verif=0
    def play(self,mvt,couleur):
        if self.verif==1:
            self.verif=2
            return print('Partie Terminée !')
        elif self.verif==2:
            return print('')
        else: 
            if mvt>self.j:
                return print('La Valeur de la colonne insérée est hors plateau ! Tentez un entier entre 0 et',self.j)
            couleur=couleur.lower() # meme si le string entré est en maj, il devient en miniscule comme demandé en instruction.
            mvt=mvt-1
            if couleur=='rouge' or couleur=='jaune':
                #for a in range(self.i): # i = la valeur maximal des lignes = dernière ligne.
                    #if self.plateau[self.i-1][mvt]== 'O' :
                        #self.plateau[self.i-1][mvt]=couleur
                        #break
                    #else :
                        #self.plateau[self.i-1-a][mvt]=couleur
                        #break
                for a in range(self.i):
                    if self.plateau[self.i-1-a][mvt]== 'O':
                        self.plateau[self.i-1-a][mvt]=couleur
                        break
                if self.plateau[0][mvt]!= 'O':
                    self.list_colonne_complète.append(mvt)
                    return print('joueur',couleur,'a saturé complètement la colonne',mvt
                                ,'! Voici la liste des colonnes saturés',self.list_colonne_complète)
            # appeler la méthode verfication_gagnant.
            # Check sur les colonnes:
            for b in range(self.j): #self.j ici correspond à la dernière colonne.
                    A=[]
                    for i in range(self.i):# hona
                        A.append(str(self.plateau[i][b]))
                    A1=A
                    A2=A
                    for i in range(len(A1)):
                        if A1.count('r')>=4:
                            B=[]
                            c1=A1.index('r')
                            for j in range(4):
                                B.append(A1[c1+j])
                            if B.count('r')==4:
                                self.verif=1
                                return print('le rouge c-a gagner !! Partie Terminée')
                            else:
                                A1.remove(A1[A1.index('r')])
                        if A2.count('j')>=4:
                            B2=[]
                            c2=A2.index('j')
                            for j in range(4):
                                B2.append(A2[c2+j])
                            if B2.count('j')==4:
                                self.verif=1
                                return print('le jaune c-a gagner !! Partie Terminée')
                            else:
                                A2.remove(A2[c2])
                    #if A.count('r')==4 :
                        #return print('le rouge à gagner !! Partie Terminée')
                        
                    #if A.count('j')==4:
                        #return print('le jaune à gagner !! Partie Terminée')
                        
            # Check sur les lignes:
            for a in range(self.i):
                A=[]
                for i in range(self.j):#hona
                    A.append(str(self.plateau[a][i]))
                    A1=A
                    A2=A
                    for i in range(len(A1)):
                        if A1.count('r')>=4:
                            B=[]
                            c1=A1.index('r')
                            for j in range(4):
                                B.append(A1[c1+j])
                            if B.count('r')==4:
                                self.verif=1
                                return print('le rouge l-a gagné !! Partie Terminée')
                            else:
                                A1.remove(A1[A1.index('r')])
                        if A2.count('j')>=4:
                            B2=[]
                            c2=A2.index('j')
                            for j in range(4):
                                B2.append(A2[c2+j])
                            if B2.count('j')==4:
                                self.verif=1
                                return print('le jaune l-a gagné !! Partie Terminée')
                            else:
                                A2.remove(A2[c2])
                #if A.count('r')==4 :
                        #return print('le rouge a gagné !! Partie Terminée')
                #if A.count('j')==4 :
                    # return print('le jaune a gagné !! Partie Terminée')
        
            # check les lignes diagonaux :
            if self.i>4 and self.j>4 :
                # cas 1 :
                D1=[]
                self.c=4
                self.v=self.i-4
                z=self.i-1
                b=self.j
                for i in range(self.c):
                    D1.append(str(self.plateau[self.v+i][b-1-i]))
                    if self.v+i==z:
                        self.v=self.v+1
                        self.c=self.c+1
                        if self.c>self.j:
                            self.c=self.j
                        A1=D1
                        A2=D1
                        for y in range(len(A1)):
                            if 'r' in A1:
                                B=[]
                                c1=A1.index('r')
                                for j in range(4):
                                    if c1+j>len(A1)-1:
                                        break
                                    B.append(A1[c1+j])
                                if B.count('r')==4:
                                    self.verif=1
                                    return print('le rouge dfd-a gagné !! Partie Terminée')
                                else:
                                    A1.remove(A1[A1.index('r')])
                            elif 'j' in A1:
                                B2=[]
                                c2=A2.index('j')
                                for j in range(4):
                                    if c2+j>len(A1)-1:
                                        break
                                    B2.append(A2[c2+j])
                                if B2.count('j')==4:
                                    self.verif=1
                                    return print('le jaune dfd-a gagné !! Partie Terminée')
                                else:
                                    A2.remove(A2[c2])
                            #if D1.count('r')==4 :
                                #return print('le rouge a gagné !! Partie Terminée')
                            #if D1.count('j')==4 :
                                #return print('le jaune a gagné !! Partie Terminée')
                    if b-1-i==0:
                        z-=1
                    if self.v==0:
                        b-=1
                        c-=1
                #cas 2 :
                D1=[]
                self.c=4
                self.v=self.i-4
                z=self.i-1
                b=self.j
                for i in range(self.c):
                    D1.append(str(self.plateau[self.v+i][i]))
                    if self.v+i==z:
                        self.v=self.v+1
                        self.c=self.c+1
                        if self.c>self.j:
                            self.c=self.j
                        A1=D1
                        A2=D1
                        for y in range(len(A1)):
                            if 'r' in A1:
                                B=[]
                                c1=A1.index('r')
                                for j in range(4):
                                    if c1+j>len(A1)-1:
                                        break
                                    B.append(A1[c1+j])
                                if B.count('r')==4:
                                    self.verif=1
                                    return print('le rouge dfind-a gagné !! Partie Terminée')
                                else:
                                    A1.remove(A1[A1.index('r')])
                            elif 'j' in A1:
                                B2=[]
                                c2=A2.index('j')
                                for j in range(4):
                                    if c2+j>len(A1)-1:
                                        break
                                    B2.append(A2[c2+j])
                                if B2.count('j')==4:
                                    self.verif=1
                                    return print('le jaune dfind-a gagné !! Partie Terminée')
                                else:
                                    A2.remove(A2[c2])
                            #if D1.count('r')==4 :
                                #return print('le rouge a gagné !! Partie Terminée')
                            #if D1.count('j')==4 :
                                #return print('le jaune a gagné !! Partie Terminée')
                    if b-1-i==0:
                        z-=1
                    if self.v==0:
                        b-=1
                        c-=1
            #cas des diagonales directs et indirects
            if self.j==self.i:
                D_direct=[]# diagonal direct
                for i in range(self.i):
                    D_direct.append(str(self.plateau[self.i-1-i][i]))
                A1=D_direct
                A2=D_direct
                for i in range(len(A1)):
                    if A1.count('r')>=4:
                        B=[]
                        c1=A1.index('r')
                        for j in range(4):
                            B.append(A1[c1+j])
                        if B.count('r')==4:
                            self.verif=1
                            return print('le rouge d-a gagné !! Partie Terminée')
                        else:
                            A1.remove(A1[A1.index('r')])
                    if A2.count('j')>=4:
                        B2=[]
                        c2=A2.index('j')
                        for j in range(4):
                            B2.append(A2[c2+j])
                        if B2.count('j')==4:
                            self.verif=1
                            return print('le jaune d-a gagné !! Partie Terminée')
                        else:
                            A2.remove(A2[c2])
                D_indirect=[] # diagonal indirect
                for i in range(self.i):
                    D_indirect.append(str(self.plateau[i][i]))
                A1=D_indirect
                A2=D_indirect
                for i in range(len(A1)):
                    if A1.count('r')>=4:
                        B=[]
                        c1=A1.index('r')
                        for j in range(4):
                            B.append(A1[c1+j])
                        if B.count('r')==4:
                            self.verif=1
                            return print('le rouge ind-a gagné !! Partie Terminée')
                        else:
                            A1.remove(A1[A1.index('r')])
                    if A2.count('j')>=4:
                        B2=[]
                        c2=A2.index('j')
                        for j in range(4):
                            B2.append(A2[c2+j])
                        if B2.count('j')==4:
                            self.verif=1
                            return print('le jaune ind-a gagné !! Partie Terminée')
                        else:
                            A2.remove(A2[c2])
                          
            
                    
            
            
                        
        
        
    def print_t(self):
        if self.verif==1 or self.verif==2 :
            return print(' ')
        else:
            return print(self.plateau)
        
        
board_test=Board(600,600)
board_test.play(1,'jaune')
#board_test.print_t()
board_test.play(1,'jaune')
#board_test.print_t()
board_test.play(1,'jaune')
#board_test.print_t()
board_test.play(1,'rouge')
#board_test.print_t()
board_test.play(1,'jaune')
#board_test.print_t()
board_test.play(1,'rouge')
#board_test.print_t()
board_test.play(2,'jaune')
#board_test.print_t()
board_test.play(2,'rouge')
##board_test.print_t()
board_test.play(2,'jaune')
board_test.print_t()
board_test.play(2,'jaune')
board_test.print_t()
board_test.play(2,'rouge')##
board_test.print_t()
board_test.play(3,'jaune')
board_test.print_t()
board_test.play(3,'rouge')
board_test.print_t()
board_test.play(3,'rouge')
board_test.print_t()
board_test.play(3,'rouge')
board_test.print_t()
board_test.play(4,'rouge')
board_test.print_t()
board_test.play(4,'jaune')
board_test.print_t()
board_test.play(4,'rouge')
board_test.print_t()
board_test.play(5,'jaune')
board_test.print_t()
board_test.play(5,'rouge')
board_test.print_t()
board_test.play(6,'rouge')
board_test.print_t()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [51], line 277
#     273             return print(self.plateau)
#     276 board_test=Board(600,600)
# --> 277 board_test.play(1,'jaune')
#     278 #board_test.print_t()
#     279 board_test.play(1,'jaune')
#
# Cell In [51], line 82, in Board.play(self, mvt, couleur)
#      80 A2=A
#      81 for i in range(len(A1)):
# ---> 82     if A1.count('r')>=4:
#      83         B=[]
#      84         c1=A1.index('r')
#
# KeyboardInterrupt:

# %%
import numpy as np

class Board(object): 
    def __init__(self,i=4,j=4):
        self.i=i
        self.j=j
        self.plateau=np.full((self.i,self.j),'O' )
        self.list_colonne_complète=[]
        self.c=0
        self.v=0
        self.verif=0
    def play(self,mvt,couleur):
        if self.verif==1:
            self.verif=2
            return print('Partie Terminée !')
        elif self.verif==2:
            return print('')
        else: 
            if mvt>self.j:
                return print('La Valeur de la colonne insérée est hors plateau ! Tentez un entier entre 0 et',self.j)
            couleur=couleur.lower() # meme si le string entré est en maj, il devient en miniscule comme demandé en instruction.
            mvt=mvt-1
            if couleur=='rouge' or couleur=='jaune':
                #for a in range(self.i): # i = la valeur maximal des lignes = dernière ligne.
                    #if self.plateau[self.i-1][mvt]== 'O' :
                        #self.plateau[self.i-1][mvt]=couleur
                        #break
                    #else :
                        #self.plateau[self.i-1-a][mvt]=couleur
                        #break
                for a in range(self.i):
                    if self.plateau[self.i-1-a][mvt]== 'O':
                        self.plateau[self.i-1-a][mvt]=couleur
                        break
                if self.plateau[0][mvt]!= 'O':
                    self.list_colonne_complète.append(mvt)
                    return print('joueur',couleur,'a saturé complètement la colonne',mvt
                                ,'! Voici la liste des colonnes saturés',self.list_colonne_complète)
            # appeler la méthode verfication_gagnant.
            # Check sur les colonnes:
            for b in range(self.j): #self.j ici correspond à la dernière colonne.
                    A=[]
                    for i in range(self.i):# hona
                        A.append(str(self.plateau[i][b]))
                        print(A)
                    A1=A
                    A2=A
                    for i in range(len(A1)):
                        if A1.count('r')>=4:
                            B=[]
                            c1=A1.index('r')
                            for j in range(4):
                                B.append(A1[c1+j])
                            if B.count('r')==4:
                                self.verif=1
                                print(A1)
                                return print('le rouge c-a gagner !! Partie Terminée')
                            else:
                                A1.remove(A1[A1.index('r')])
                        if A2.count('j')>=4:
                            B2=[]
                            c2=A2.index('j')
                            for j in range(4):
                                B2.append(A2[c2+j])
                            if B2.count('j')==4:
                                self.verif=1
                                return print('le jaune c-a gagner !! Partie Terminée')
                            else:
                                A2.remove(A2[c2])
                    #if A.count('r')==4 :
                        #return print('le rouge à gagner !! Partie Terminée')
                        
                    #if A.count('j')==4:
                        #return print('le jaune à gagner !! Partie Terminée')
                        
            # Check sur les lignes:
            for a in range(self.i):
                A=[]
                for i in range(self.j):#hona
                    A.append(str(self.plateau[a][i]))
                    A1=A
                    A2=A
                    for i in range(len(A1)):
                        if A1.count('r')>=4:
                            B=[]
                            c1=A1.index('r')
                            for j in range(4):
                                B.append(A1[c1+j])
                            if B.count('r')==4:
                                self.verif=1
                                return print('le rouge l-a gagné !! Partie Terminée')
                            else:
                                A1.remove(A1[A1.index('r')])
                        if A2.count('j')>=4:
                            B2=[]
                            c2=A2.index('j')
                            for j in range(4):
                                B2.append(A2[c2+j])
                            if B2.count('j')==4:
                                self.verif=1
                                return print('le jaune l-a gagné !! Partie Terminée')
                            else:
                                A2.remove(A2[c2])
                #if A.count('r')==4 :
                        #return print('le rouge a gagné !! Partie Terminée')
                #if A.count('j')==4 :
                    # return print('le jaune a gagné !! Partie Terminée')
        
            # check les lignes diagonaux :
            if self.i>4 and self.j>4 :
                # cas 1 :
                D1=[]
                self.c=4
                self.v=self.i-4
                z=self.i-1
                b=self.j
                for i in range(self.c):
                    D1.append(str(self.plateau[self.v+i][b-1-i]))
                    if self.v+i==z:
                        self.v=self.v+1
                        self.c=self.c+1
                        if self.c>self.j:
                            self.c=self.j
                        A1=D1
                        A2=D1
                        for y in range(len(A1)):
                            if 'r' in A1:
                                B=[]
                                c1=A1.index('r')
                                for j in range(4):
                                    if c1+j>len(A1)-1:
                                        break
                                    B.append(A1[c1+j])
                                if B.count('r')==4:
                                    self.verif=1
                                    return print('le rouge dfd-a gagné !! Partie Terminée')
                                else:
                                    A1.remove(A1[A1.index('r')])
                            elif 'j' in A1:
                                B2=[]
                                c2=A2.index('j')
                                for j in range(4):
                                    if c2+j>len(A1)-1:
                                        break
                                    B2.append(A2[c2+j])
                                if B2.count('j')==4:
                                    self.verif=1
                                    return print('le jaune dfd-a gagné !! Partie Terminée')
                                else:
                                    A2.remove(A2[c2])
                            #if D1.count('r')==4 :
                                #return print('le rouge a gagné !! Partie Terminée')
                            #if D1.count('j')==4 :
                                #return print('le jaune a gagné !! Partie Terminée')
                    if b-1-i==0:
                        z-=1
                    if self.v==0:
                        b-=1
                        c-=1
                #cas 2 :
                D1=[]
                self.c=4
                self.v=self.i-4
                z=self.i-1
                b=self.j
                for i in range(self.c):
                    D1.append(str(self.plateau[self.v+i][i]))
                    if self.v+i==z:
                        self.v=self.v+1
                        self.c=self.c+1
                        if self.c>self.j:
                            self.c=self.j
                        A1=D1
                        A2=D1
                        for y in range(len(A1)):
                            if 'r' in A1:
                                B=[]
                                c1=A1.index('r')
                                for j in range(4):
                                    if c1+j>len(A1)-1:
                                        break
                                    B.append(A1[c1+j])
                                if B.count('r')==4:
                                    self.verif=1
                                    return print('le rouge dfind-a gagné !! Partie Terminée')
                                else:
                                    A1.remove(A1[A1.index('r')])
                            elif 'j' in A1:
                                B2=[]
                                c2=A2.index('j')
                                for j in range(4):
                                    if c2+j>len(A1)-1:
                                        break
                                    B2.append(A2[c2+j])
                                if B2.count('j')==4:
                                    self.verif=1
                                    return print('le jaune dfind-a gagné !! Partie Terminée')
                                else:
                                    A2.remove(A2[c2])
                            #if D1.count('r')==4 :
                                #return print('le rouge a gagné !! Partie Terminée')
                            #if D1.count('j')==4 :
                                #return print('le jaune a gagné !! Partie Terminée')
                    if b-1-i==0:
                        z-=1
                    if self.v==0:
                        b-=1
                        c-=1
            #cas des diagonales directs et indirects
            if self.j==self.i:
                D_direct=[]# diagonal direct
                for i in range(self.i):
                    D_direct.append(str(self.plateau[self.i-1-i][i]))
                A1=D_direct
                A2=D_direct
                for i in range(len(A1)):
                    if A1.count('r')>=4:
                        B=[]
                        c1=A1.index('r')
                        for j in range(4):
                            B.append(A1[c1+j])
                        if B.count('r')==4:
                            self.verif=1
                            return print('le rouge d-a gagné !! Partie Terminée')
                        else:
                            A1.remove(A1[A1.index('r')])
                    if A2.count('j')>=4:
                        B2=[]
                        c2=A2.index('j')
                        for j in range(4):
                            B2.append(A2[c2+j])
                        if B2.count('j')==4:
                            self.verif=1
                            return print('le jaune d-a gagné !! Partie Terminée')
                        else:
                            A2.remove(A2[c2])
                D_indirect=[] # diagonal indirect
                for i in range(self.i):
                    D_indirect.append(str(self.plateau[i][i]))
                A1=D_indirect
                A2=D_indirect
                for i in range(len(A1)):
                    if A1.count('r')>=4:
                        B=[]
                        c1=A1.index('r')
                        for j in range(4):
                            B.append(A1[c1+j])
                        if B.count('r')==4:
                            self.verif=1
                            return print('le rouge ind-a gagné !! Partie Terminée')
                        else:
                            A1.remove(A1[A1.index('r')])
                    if A2.count('j')>=4:
                        B2=[]
                        c2=A2.index('j')
                        for j in range(4):
                            B2.append(A2[c2+j])
                        if B2.count('j')==4:
                            self.verif=1
                            return print('le jaune ind-a gagné !! Partie Terminée')
                        else:
                            A2.remove(A2[c2])
                          
            
                    
            
            
                        
        
        
    def print_t(self):
        if self.verif==1 or self.verif==2 :
            return print('')
        else:
            return print(self.plateau)
        
        
board_test=Board(10,10)
board_test.play(1,'jaune')
board_test.print_t()
board_test.play(1,'jaune')
board_test.print_t()
board_test.play(1,'jaune')
board_test.print_t()
board_test.play(1,'rouge')
board_test.print_t()
board_test.play(1,'jaune')
board_test.print_t()
board_test.play(1,'rouge')
board_test.print_t()
board_test.play(2,'jaune')
board_test.print_t()
board_test.play(2,'rouge')
board_test.print_t()
board_test.play(2,'rouge')
board_test.print_t()
board_test.play(2,'rouge')
board_test.print_t()
board_test.play(2,'rouge')
board_test.print_t()
board_test.play(3,'rouge')
board_test.print_t()
board_test.play(3,'rouge')
board_test.print_t()
board_test.play(3,'rouge')
board_test.print_t()
board_test.play(3,'rouge')
board_test.print_t()
board_test.play(4,'rouge')
board_test.print_t()
board_test.play(4,'rouge')
board_test.print_t()
board_test.play(4,'rouge')
board_test.print_t()
board_test.play(5,'rouge')
board_test.print_t()
board_test.play(5,'rouge')
board_test.print_t()
board_test.play(6,'rouge')
board_test.print_t()
# Out:
# ['O']
# ['O', 'O']
# ['O', 'O', 'O']
# ['O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'j']
# ['O']
# ['O', 'O']
# ['O', 'O', 'O']
# ['O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O']
# ['O', 'O']
# ['O', 'O', 'O']
# ['O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O']
# ['O', 'O']
# ['O', 'O', 'O']
# ['O', 'O', 'O', 'O']
# ...

# %%
board_test=Board(6,6)
board_test.play(1,'jaune')
board_test.print_t()
board_test.play(1,'jaune')
board_test.print_t()
board_test.play(1,'jaune')
board_test.print_t()
board_test.play(1,'rouge')
board_test.print_t()
board_test.play(1,'jaune')
board_test.print_t()
board_test.play(1,'rouge')
board_test.print_t()
board_test.play(2,'jaune')
board_test.print_t()
board_test.play(2,'rouge')
board_test.print_t()
board_test.play(2,'rouge')
board_test.print_t()
board_test.play(2,'rouge')
board_test.print_t()
board_test.play(2,'rouge')
board_test.print_t()
board_test.play(3,'rouge')
board_test.print_t()
board_test.play(3,'rouge')
board_test.print_t()
board_test.play(3,'rouge')
board_test.print_t()
board_test.play(3,'rouge')
board_test.print_t()
board_test.play(4,'rouge')
board_test.print_t()
board_test.play(4,'rouge')
board_test.print_t()
board_test.play(4,'rouge')
board_test.print_t()
board_test.play(5,'rouge')
board_test.print_t()
board_test.play(5,'rouge')
board_test.print_t()
board_test.play(6,'rouge')
board_test.print_t()
# Out:
# ['O'] 2 4 -3
# ['O', 'O'] 2 4 -2
# ['O', 'O', 'O'] 2 4 -1
# ['O', 'O', 'O', 'O'] 2 4 0
# ini wlidi dilyass indirect ['O'] (0, 0)
# ini wlidi dilyass indirect ['O', 'O'] (1, 1)
# ini wlidi dilyass indirect ['O', 'O', 'O'] (2, 2)
# ini wlidi dilyass indirect ['O', 'O', 'O', 'O'] (3, 3)
# ini wlidi dilyass indirect ['O', 'O', 'O', 'O', 'O'] (4, 4)
# ini wlidi dilyass indirect ['O', 'O', 'O', 'O', 'O', 'O'] (5, 5)
# [['O' 'O' 'O' 'O' 'O' 'O']
#  ['O' 'O' 'O' 'O' 'O' 'O']
#  ['O' 'O' 'O' 'O' 'O' 'O']
#  ['O' 'O' 'O' 'O' 'O' 'O']
#  ['O' 'O' 'O' 'O' 'O' 'O']
#  ['j' 'O' 'O' 'O' 'O' 'O']]
# ['O'] 2 4 -3
# ['O', 'O'] 2 4 -2
# ['O', 'O', 'O'] 2 4 -1
# ['O', 'O', 'O', 'O'] 2 4 0
# ini wlidi dilyass indirect ['O'] (0, 0)
# ini wlidi dilyass indirect ['O', 'O'] (1, 1)
# ini wlidi dilyass indirect ['O', 'O', 'O'] (2, 2)
# ini wlidi dilyass indirect ['O', 'O', 'O', 'O'] (3, 3)
# ini wlidi dilyass indirect ['O', 'O', 'O', 'O', 'O'] (4, 4)
# ...

# %%
board_test=Board(6,6)
board_test.play(1,'jaune')
board_test.print_t()
board_test.play(1,'jaune')
board_test.print_t()
board_test.play(1,'jaune')
board_test.print_t()
board_test.play(1,'rouge')
board_test.print_t()
board_test.play(1,'jaune')
board_test.print_t()
board_test.play(1,'rouge')
board_test.print_t()
board_test.play(2,'jaune')
board_test.print_t()
board_test.play(2,'rouge')
board_test.print_t()
board_test.play(2,'rouge')
board_test.print_t()
board_test.play(2,'rouge')
board_test.print_t()
board_test.play(2,'rouge')
board_test.print_t()
board_test.play(3,'rouge')
board_test.print_t()
board_test.play(3,'rouge')
board_test.print_t()
board_test.play(3,'rouge')
board_test.print_t()
board_test.play(3,'rouge')
board_test.print_t()
board_test.play(4,'rouge')
board_test.print_t()
board_test.play(5,'rouge')
board_test.play(5,'rouge')
board_test.print_t()


board_test.play(6,'rouge')
board_test.print_t()
# Out:
# ['O'] 2 4 -3
# ['O', 'O'] 2 4 -2
# ['O', 'O', 'O'] 2 4 -1
# ['O', 'O', 'O', 'O'] 2 4 0
# ini wlidi dilyass indirect ['O'] (0, 0)
# ini wlidi dilyass indirect ['O', 'O'] (1, 1)
# ini wlidi dilyass indirect ['O', 'O', 'O'] (2, 2)
# ini wlidi dilyass indirect ['O', 'O', 'O', 'O'] (3, 3)
# ini wlidi dilyass indirect ['O', 'O', 'O', 'O', 'O'] (4, 4)
# ini wlidi dilyass indirect ['O', 'O', 'O', 'O', 'O', 'O'] (5, 5)
# [['O' 'O' 'O' 'O' 'O' 'O']
#  ['O' 'O' 'O' 'O' 'O' 'O']
#  ['O' 'O' 'O' 'O' 'O' 'O']
#  ['O' 'O' 'O' 'O' 'O' 'O']
#  ['O' 'O' 'O' 'O' 'O' 'O']
#  ['j' 'O' 'O' 'O' 'O' 'O']]
# ['O'] 2 4 -3
# ['O', 'O'] 2 4 -2
# ['O', 'O', 'O'] 2 4 -1
# ['O', 'O', 'O', 'O'] 2 4 0
# ini wlidi dilyass indirect ['O'] (0, 0)
# ini wlidi dilyass indirect ['O', 'O'] (1, 1)
# ini wlidi dilyass indirect ['O', 'O', 'O'] (2, 2)
# ini wlidi dilyass indirect ['O', 'O', 'O', 'O'] (3, 3)
# ini wlidi dilyass indirect ['O', 'O', 'O', 'O', 'O'] (4, 4)
# ...

# %%
import numpy as np
np.zeros((1 , 3))
np.zeros((1 , 3),dtype='int')
# Out:
# array([[0, 0, 0]])

# %%
couleur="BABAHA"
couleur=couleur.lower() 
print(couleur)
# Out:
# babaha
